# %%
# Import the dependencies.
import pandas as pd
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs
coordinates = list(lat_lngs)

# %%
cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    if city not in cities:
        cities.append(city)

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []
record_count = 1

for i, city in enumerate(cities):

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record and the city.
    print(f"Processing Record {record_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_type = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_weather_type})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 | avarua
# Processing Record 2 | poum
# Processing Record 3 | yellowknife
# Processing Record 4 | hit
# Processing Record 5 | upernavik
# Processing Record 6 | moree
# Processing Record 7 | tvedestrand
# Processing Record 8 | karratha
# Processing Record 9 | tasiilaq
# Processing Record 10 | naze
# Processing Record 11 | rio grande
# Processing Record 12 | bilma
# Processing Record 13 | erenhot
# Processing Record 14 | thompson
# Processing Record 15 | skibbereen
# Processing Record 16 | puerto ayora
# Processing Record 17 | ushuaia
# Processing Record 18 | mayna
# Processing Record 19 | dikson
# Processing Record 20 | punta arenas
# Processing Record 21 | bethel
# Processing Record 22 | garowe
# Processing Record 23 | torbay
# Processing Record 24 | santiago del estero
# Processing Record 25 | vaini
# Processing Record 26 | cruzeiro do sul
# Processing Record 27 | saurimo
# Processing Record 28 | busselton
# Processing Record 29 | henties bay
# Processing Record 30 | khatanga
# Processing Record 31 | astakos
# Processing Record 32 | alofi
# Processing Record 33 | colesberg
# Processing Record 34 | shiyan
# Processing Record 35 | bluff
# Processing Record 36 | le vauclin
# Processing Record 37 | rikitea
# Processing Record 38 | dunedin
# Processing Record 39 | severnyy-kospashskiy
# Processing Record 40 | vao
# Processing Record 41 | linfen
# Processing Record 42 | airai
# Processing Record 43 | mataura
# Processing Record 44 | albany
# Processing Record 45 | jamestown
# Processing Record 46 | port alfred
# Processing Record 47 | marsabit
# Processing Record 48 | baoshan
# Processing Record 49 | lompoc
# Processing Record 50 | roma
# Processing Record 51 | ribeira grande
# Processing Record 52 | kahului
# Processing Record 53 | belushya guba
# City not found. Skipping...
# Processing Record 54 | ponta do sol
# Processing Record 55 | alekseyevka
# Processing Record 56 | leningradskiy
# Processing Record 57 | half moon bay
# Processing Record 58 | taolanaro
# City not found. Skipping...
# Processing Record 59 | atuona
# Processing Record 60 | hithadhoo
# Processing Record 61 | chokurdakh
# Processing Record 62 | mvuma
# Processing Record 63 | zhengjiatun
# Processing Record 64 | santa luzia
# Processing Record 65 | saint-philippe
# Processing Record 66 | gangapur
# Processing Record 67 | flinders
# Processing Record 68 | juneau
# Processing Record 69 | synya
# Processing Record 70 | castro
# Processing Record 71 | kumluca
# Processing Record 72 | attawapiskat
# City not found. Skipping...
# Processing Record 73 | nailsea
# Processing Record 74 | batemans bay
# Processing Record 75 | cape town
# Processing Record 76 | longlac
# City not found. Skipping...
# Processing Record 77 | hilo
# Processing Record 78 | miles city
# Processing Record 79 | tenosique
# Processing Record 80 | adrar
# Processing Record 81 | luderitz
# Processing Record 82 | vaitupu
# City not found. Skipping...
# Processing Record 83 | carnarvon
# Processing Record 84 | saint george
# Processing Record 85 | yar-sale
# Processing Record 86 | havelock
# Processing Record 87 | khonuu
# City not found. Skipping...
# Processing Record 88 | geraldton
# Processing Record 89 | hobart
# Processing Record 90 | severo-kurilsk
# Processing Record 91 | oussouye
# Processing Record 92 | grindavik
# Processing Record 93 | barrow
# Processing Record 94 | nanortalik
# Processing Record 95 | tandil
# Processing Record 96 | wufeng
# Processing Record 97 | grand river south east
# City not found. Skipping...
# Processing Record 98 | klaksvik
# Processing Record 99 | namatanai
# Processing Record 100 | zeya
# Processing Record 101 | pangai
# Processing Record 102 | great falls
# Processing Record 103 | taquaritinga
# Processing Record 104 | sisimiut
# Processing Record 105 | bredasdorp
# Processing Record 106 | itaituba
# Processing Record 107 | novo cruzeiro
# Processing Record 108 | guerrero negro
# Processing Record 109 | husavik
# Processing Record 110 | tuatapere
# Processing Record 111 | sitka
# Processing Record 112 | gari
# Processing Record 113 | chuy
# Processing Record 114 | hermanus
# Processing Record 115 | bengkulu
# Processing Record 116 | cherskiy
# Processing Record 117 | saskylakh
# Processing Record 118 | stavern
# Processing Record 119 | waverly
# Processing Record 120 | bac lieu
# Processing Record 121 | nueva concepcion
# Processing Record 122 | humaita
# Processing Record 123 | nizhneyansk
# City not found. Skipping...
# Processing Record 124 | nabire
# Processing Record 125 | yulara
# Processing Record 126 | mirnyy
# Processing Record 127 | lagoa
# Processing Record 128 | tiksi
# Processing Record 129 | kapaa
# Processing Record 130 | rawson
# Processing Record 131 | egvekinot
# Processing Record 132 | saleaula
# City not found. Skipping...
# Processing Record 133 | victoria
# Processing Record 134 | kearney
# Processing Record 135 | saldanha
# Processing Record 136 | mys shmidta
# City not found. Skipping...
# Processing Record 137 | west wendover
# Processing Record 138 | lazaro cardenas
# Processing Record 139 | miandrivazo
# Processing Record 140 | katsuura
# Processing Record 141 | ancud
# Processing Record 142 | zhigansk
# Processing Record 143 | najran
# Processing Record 144 | qaanaaq
# Processing Record 145 | sabinas
# Processing Record 146 | barentsburg
# City not found. Skipping...
# Processing Record 147 | sao filipe
# Processing Record 148 | areosa
# Processing Record 149 | lavrentiya
# Processing Record 150 | sayyan
# Processing Record 151 | georgetown
# Processing Record 152 | tubuala
# Processing Record 153 | provideniya
# Processing Record 154 | hasaki
# Processing Record 155 | lebu
# Processing Record 156 | new norfolk
# Processing Record 157 | bandarbeyla
# Processing Record 158 | ulladulla
# Processing Record 159 | nikolskoye
# Processing Record 160 | ust-tsilma
# Processing Record 161 | cabo san lucas
# Processing Record 162 | butaritari
# Processing Record 163 | srednekolymsk
# Processing Record 164 | awjilah
# Processing Record 165 | saint-michel-des-saints
# Processing Record 166 | kidal
# Processing Record 167 | plettenberg bay
# Processing Record 168 | umzimvubu
# City not found. Skipping...
# Processing Record 169 | banjar
# Processing Record 170 | mezhdurechensk
# Processing Record 171 | jalu
# Processing Record 172 | san javier
# Processing Record 173 | camana
# Processing Record 174 | east london
# Processing Record 175 | turukhansk
# Processing Record 176 | beringovskiy
# Processing Record 177 | laje
# Processing Record 178 | guiratinga
# Processing Record 179 | faanui
# Processing Record 180 | thinadhoo
# Processing Record 181 | olafsvik
# Processing Record 182 | vicuna
# Processing Record 183 | sohag
# Processing Record 184 | cidreira
# Processing Record 185 | tubruq
# City not found. Skipping...
# Processing Record 186 | pangnirtung
# Processing Record 187 | meambar
# City not found. Skipping...
# Processing Record 188 | okha
# Processing Record 189 | ostrovnoy
# Processing Record 190 | norman wells
# Processing Record 191 | nhulunbuy
# Processing Record 192 | maceio
# Processing Record 193 | ginir
# Processing Record 194 | nushki
# Processing Record 195 | krasnyy gulyay
# Processing Record 196 | verkhnevilyuysk
# Processing Record 197 | temnikov
# Processing Record 198 | gushikawa
# Processing Record 199 | ancona
# Processing Record 200 | aksu
# Processing Record 201 | paradwip
# City not found. Skipping...
# Processing Record 202 | esso
# Processing Record 203 | yelizovo
# Processing Record 204 | meulaboh
# Processing Record 205 | kavaratti
# Processing Record 206 | constitucion
# Processing Record 207 | ust-nera
# Processing Record 208 | xianyang
# Processing Record 209 | port elizabeth
# Processing Record 210 | vestmanna
# Processing Record 211 | vila velha
# Processing Record 212 | kaitangata
# Processing Record 213 | mugur-aksy
# Processing Record 214 | mayo
# Processing Record 215 | madang
# Processing Record 216 | simao
# Processing Record 217 | mahibadhoo
# Processing Record 218 | dandong
# Processing Record 219 | pouebo
# Processing Record 220 | mayumba
# Processing Record 221 | kautokeino
# Processing Record 222 | luang prabang
# Processing Record 223 | san andres
# Processing Record 224 | megion
# Processing Record 225 | ranong
# Processing Record 226 | bargal
# City not found. Skipping...
# Processing Record 227 | qaqortoq
# Processing Record 228 | vaux-sur-sure
# Processing Record 229 | vostok
# Processing Record 230 | ayan
# Processing Record 231 | gimbi
# Processing Record 232 | cabra
# Processing Record 233 | ijaki
# City not found. Skipping...
# Processing Record 234 | quelimane
# Processing Record 235 | ikom
# Processing Record 236 | bambous virieux
# Processing Record 237 | acarau
# Processing Record 238 | coihaique
# Processing Record 239 | dorado
# Processing Record 240 | piacabucu
# Processing Record 241 | wattegama
# Processing Record 242 | nevelsk
# Processing Record 243 | talaya
# Processing Record 244 | barra da estiva
# Processing Record 245 | saint-denis
# Processing Record 246 | sioux lookout
# Processing Record 247 | sandeid
# Processing Record 248 | mount gambier
# Processing Record 249 | osijek
# Processing Record 250 | ningbo
# Processing Record 251 | patos
# Processing Record 252 | charcas
# Processing Record 253 | bonnyville
# Processing Record 254 | astoria
# Processing Record 255 | ambilobe
# Processing Record 256 | vila
# Processing Record 257 | mutsamudu
# City not found. Skipping...
# Processing Record 258 | thoen
# Processing Record 259 | sakakah
# Processing Record 260 | maple creek
# Processing Record 261 | vila franca do campo
# Processing Record 262 | karmala
# Processing Record 263 | auki
# Processing Record 264 | fortuna
# Processing Record 265 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 266 | chipinge
# Processing Record 267 | tsihombe
# City not found. Skipping...
# Processing Record 268 | warqla
# City not found. Skipping...
# Processing Record 269 | namibe
# Processing Record 270 | talnakh
# Processing Record 271 | la ronge
# Processing Record 272 | cochrane
# Processing Record 273 | hailey
# Processing Record 274 | sawtell
# Processing Record 275 | kalmunai
# Processing Record 276 | mar del plata
# Processing Record 277 | asyut
# Processing Record 278 | kavieng
# Processing Record 279 | lahaina
# Processing Record 280 | fairbanks
# Processing Record 281 | verkhnyaya inta
# Processing Record 282 | vestmannaeyjar
# Processing Record 283 | mahebourg
# Processing Record 284 | qianguo
# Processing Record 285 | souillac
# Processing Record 286 | linapacan
# City not found. Skipping...
# Processing Record 287 | taltal
# Processing Record 288 | beloha
# Processing Record 289 | honiara
# Processing Record 290 | yuanping
# Processing Record 291 | maxixe
# Processing Record 292 | jiddah
# City not found. Skipping...
# Processing Record 293 | high prairie
# Processing Record 294 | mansehra
# Processing Record 295 | ternate
# Processing Record 296 | port hardy
# Processing Record 297 | nizhneangarsk
# Processing Record 298 | general roca
# Processing Record 299 | eureka
# Processing Record 300 | sentyabrskiy
# City not found. Skipping...
# Processing Record 301 | nenjiang
# Processing Record 302 | samusu
# City not found. Skipping...
# Processing Record 303 | batagay-alyta
# Processing Record 304 | iqaluit
# Processing Record 305 | monterey
# Processing Record 306 | pevek
# Processing Record 307 | grand gaube
# Processing Record 308 | vagamo
# Processing Record 309 | greymouth
# Processing Record 310 | llanes
# Processing Record 311 | roald
# Processing Record 312 | lovozero
# Processing Record 313 | onega
# Processing Record 314 | sosnovo-ozerskoye
# Processing Record 315 | mungaa
# Processing Record 316 | lloydminster
# Processing Record 317 | bom jesus
# Processing Record 318 | anshun
# Processing Record 319 | dinguiraye
# Processing Record 320 | natal
# Processing Record 321 | ayolas
# Processing Record 322 | mahadday weyne
# City not found. Skipping...
# Processing Record 323 | nemuro
# Processing Record 324 | mehamn
# Processing Record 325 | berlevag
# Processing Record 326 | san patricio
# Processing Record 327 | robe
# Processing Record 328 | weligama
# Processing Record 329 | fonte boa
# Processing Record 330 | bolungarvik
# City not found. Skipping...
# Processing Record 331 | wanaka
# Processing Record 332 | slave lake
# Processing Record 333 | pisco
# Processing Record 334 | andros town
# Processing Record 335 | manokwari
# Processing Record 336 | roseburg
# Processing Record 337 | rapallo
# Processing Record 338 | irati
# Processing Record 339 | cazaje
# City not found. Skipping...
# Processing Record 340 | amderma
# City not found. Skipping...
# Processing Record 341 | carbonia
# Processing Record 342 | buala
# Processing Record 343 | saint-augustin
# Processing Record 344 | arraial do cabo
# Processing Record 345 | kaspiyskiy
# Processing Record 346 | hervey bay
# Processing Record 347 | tel aviv-yafo
# Processing Record 348 | aquiraz
# Processing Record 349 | bilibino
# Processing Record 350 | kupang
# Processing Record 351 | ettenheim
# Processing Record 352 | angelholm
# City not found. Skipping...
# Processing Record 353 | liminangcong
# City not found. Skipping...
# Processing Record 354 | gurlan
# Processing Record 355 | arlit
# Processing Record 356 | peleduy
# Processing Record 357 | clyde river
# Processing Record 358 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 359 | narsaq
# Processing Record 360 | port hawkesbury
# Processing Record 361 | prince rupert
# Processing Record 362 | alamos
# Processing Record 363 | iquitos
# Processing Record 364 | longyearbyen
# Processing Record 365 | wawa
# Processing Record 366 | iwanai
# Processing Record 367 | vracov
# Processing Record 368 | mago
# Processing Record 369 | imeni zhelyabova
# Processing Record 370 | hambantota
# Processing Record 371 | wynyard
# Processing Record 372 | alexandria
# Processing Record 373 | pacific grove
# Processing Record 374 | inderborskiy
# City not found. Skipping...
# Processing Record 375 | pervomayskoye
# Processing Record 376 | batagay
# Processing Record 377 | chegdomyn
# Processing Record 378 | katherine
# Processing Record 379 | tumannyy
# City not found. Skipping...
# Processing Record 380 | baruun-urt
# Processing Record 381 | maldonado
# Processing Record 382 | el cocuy
# Processing Record 383 | kijang
# Processing Record 384 | mangrol
# Processing Record 385 | salalah
# Processing Record 386 | makat
# Processing Record 387 | cockburn town
# Processing Record 388 | komsomolskiy
# Processing Record 389 | vahan
# Processing Record 390 | vanimo
# Processing Record 391 | gurgan
# City not found. Skipping...
# Processing Record 392 | kadykchan
# City not found. Skipping...
# Processing Record 393 | tuktoyaktuk
# Processing Record 394 | cayenne
# Processing Record 395 | lata
# Processing Record 396 | tual
# Processing Record 397 | waipawa
# Processing Record 398 | kourou
# Processing Record 399 | kutum
# Processing Record 400 | kyaikkami
# Processing Record 401 | quatre cocos
# Processing Record 402 | pijijiapan
# Processing Record 403 | hadishahr
# Processing Record 404 | sabang
# Processing Record 405 | vryburg
# Processing Record 406 | carson city
# Processing Record 407 | hami
# Processing Record 408 | green river
# Processing Record 409 | teluknaga
# Processing Record 410 | hailar
# Processing Record 411 | himora
# City not found. Skipping...
# Processing Record 412 | dawson creek
# Processing Record 413 | kodiak
# Processing Record 414 | ugoofaaru
# Processing Record 415 | benjamin aceval
# Processing Record 416 | yarada
# Processing Record 417 | bathsheba
# Processing Record 418 | hamilton
# Processing Record 419 | boa vista
# Processing Record 420 | kiri buru
# Processing Record 421 | kotelnikovo
# Processing Record 422 | olhao
# Processing Record 423 | fukue
# Processing Record 424 | codrington
# Processing Record 425 | kamenka
# Processing Record 426 | utete
# Processing Record 427 | mpika
# Processing Record 428 | aklavik
# Processing Record 429 | gambela
# Processing Record 430 | anadyr
# Processing Record 431 | puerto quijarro
# Processing Record 432 | umm kaddadah
# Processing Record 433 | faya
# Processing Record 434 | kruisfontein
# Processing Record 435 | hatsukaichi
# Processing Record 436 | mlowo
# Processing Record 437 | tateyama
# Processing Record 438 | altamont
# Processing Record 439 | salina cruz
# Processing Record 440 | paidha
# Processing Record 441 | ambon
# Processing Record 442 | robertsport
# Processing Record 443 | liverpool
# Processing Record 444 | erzin
# Processing Record 445 | dinsor
# City not found. Skipping...
# Processing Record 446 | eyl
# Processing Record 447 | komsomolets
# Processing Record 448 | aykhal
# Processing Record 449 | antalaha
# Processing Record 450 | cam ranh
# Processing Record 451 | te anau
# Processing Record 452 | arkhangelsk
# Processing Record 453 | halalo
# City not found. Skipping...
# Processing Record 454 | grand-santi
# Processing Record 455 | nuevo imperial
# Processing Record 456 | bonavista
# Processing Record 457 | lokken verk
# City not found. Skipping...
# Processing Record 458 | isangel
# Processing Record 459 | ukiah
# Processing Record 460 | kawalu
# Processing Record 461 | saint-pierre
# Processing Record 462 | keti bandar
# Processing Record 463 | marsh harbour
# Processing Record 464 | deputatskiy
# Processing Record 465 | matamoros
# Processing Record 466 | doha
# Processing Record 467 | azimur
# City not found. Skipping...
# Processing Record 468 | bull savanna
# Processing Record 469 | paamiut
# Processing Record 470 | uyar
# Processing Record 471 | gadwal
# Processing Record 472 | okhotsk
# Processing Record 473 | fomboni
# Processing Record 474 | gorele
# Processing Record 475 | brae
# Processing Record 476 | esperance
# Processing Record 477 | trinidad
# Processing Record 478 | vallenar
# Processing Record 479 | colac
# Processing Record 480 | pokhara
# Processing Record 481 | ust-kuyga
# Processing Record 482 | venice
# Processing Record 483 | puerto leguizamo
# Processing Record 484 | urengoy
# Processing Record 485 | chapleau
# Processing Record 486 | trairi
# Processing Record 487 | magaria
# Processing Record 488 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 489 | kayerkan
# Processing Record 490 | ransang
# Processing Record 491 | celestun
# Processing Record 492 | dzhusaly
# City not found. Skipping...
# Processing Record 493 | lar
# Processing Record 494 | ambunti
# Processing Record 495 | high level
# Processing Record 496 | altay
# Processing Record 497 | qurayyat
# Processing Record 498 | guicheng
# City not found. Skipping...
# Processing Record 499 | toppenish
# Processing Record 500 | walvis bay
# Processing Record 501 | alice springs
# Processing Record 502 | thaton
# Processing Record 503 | baracoa
# Processing Record 504 | syasstroy
# Processing Record 505 | kamaishi
# Processing Record 506 | sulangan
# Processing Record 507 | nelspruit
# Processing Record 508 | sibolga
# Processing Record 509 | havoysund
# Processing Record 510 | barcelona
# Processing Record 511 | sri aman
# Processing Record 512 | tipitapa
# Processing Record 513 | abu dhabi
# Processing Record 514 | sao lourenco do sul
# Processing Record 515 | port macquarie
# Processing Record 516 | minab
# Processing Record 517 | rion
# Processing Record 518 | neiafu
# Processing Record 519 | along
# Processing Record 520 | gorontalo
# Processing Record 521 | nishihara
# Processing Record 522 | ahipara
# Processing Record 523 | rome
# Processing Record 524 | mount isa
# Processing Record 525 | yirol
# City not found. Skipping...
# Processing Record 526 | tarudant
# City not found. Skipping...
# Processing Record 527 | huarmey
# Processing Record 528 | bouake
# Processing Record 529 | general pico
# Processing Record 530 | kirishi
# Processing Record 531 | gamba
# Processing Record 532 | belaya gora
# Processing Record 533 | alotau
# City not found. Skipping...
# Processing Record 534 | broome
# Processing Record 535 | gilbues
# Processing Record 536 | gao
# Processing Record 537 | mangaratiba
# Processing Record 538 | rancho palos verdes
# Processing Record 539 | artyk
# City not found. Skipping...
# Processing Record 540 | toora-khem
# Processing Record 541 | houma
# Processing Record 542 | innisfail
# Processing Record 543 | coquimbo
# Processing Record 544 | komyshnya
# Processing Record 545 | zasechnoye
# Processing Record 546 | esik
# Processing Record 547 | port blair
# Processing Record 548 | karaul
# City not found. Skipping...
# Processing Record 549 | pemba
# Processing Record 550 | ornskoldsvik
# Processing Record 551 | utkivka
# Processing Record 552 | jeremie
# Processing Record 553 | lahad datu
# Processing Record 554 | plastun
# Processing Record 555 | ketchikan
# Processing Record 556 | idenao
# Processing Record 557 | sivas
# Processing Record 558 | harper
# Processing Record 559 | baripada
# Processing Record 560 | lorengau
# Processing Record 561 | marovoay
# Processing Record 562 | russkaya polyana
# Processing Record 563 | paveh
# Processing Record 564 | vardo
# Processing Record 565 | abilene
# Processing Record 566 | jabiru
# City not found. Skipping...
# Processing Record 567 | bur gabo
# City not found. Skipping...
# Processing Record 568 | zempoala
# Processing Record 569 | port-de-paix
# City not found. Skipping...
# Processing Record 570 | ngukurr
# City not found. Skipping...
# Processing Record 571 | belgrade
# Processing Record 572 | mainburg
# Processing Record 573 | aboso
# Processing Record 574 | monteagudo
# Processing Record 575 | ilulissat
# Processing Record 576 | nouadhibou
# Processing Record 577 | taseyevo
# Processing Record 578 | kirakira
# Processing Record 579 | puerto escondido
# Processing Record 580 | rumoi
# Processing Record 581 | khandyga
# Processing Record 582 | orocue
# Processing Record 583 | hihifo
# City not found. Skipping...
# Processing Record 584 | maturin
# Processing Record 585 | koumac
# Processing Record 586 | nome
# Processing Record 587 | copiapo
# Processing Record 588 | verkhovye
# Processing Record 589 | powell
# Processing Record 590 | zyryanovsk
# Processing Record 591 | mayor pablo lagerenza
# Processing Record 592 | arrecife
# Processing Record 593 | padang
# Processing Record 594 | kaberamaido
# Processing Record 595 | doka
# Processing Record 596 | policoro
# Processing Record 597 | petropavlovsk-kamchatskiy
# Processing Record 598 | mnogovershinnyy
# Processing Record 599 | galgani
# City not found. Skipping...
# Processing Record 600 | chateaubelair
# Processing Record 601 | abu zabad
# Processing Record 602 | rawannawi
# City not found. Skipping...
# Processing Record 603 | kaele
# Processing Record 604 | keffi
# Processing Record 605 | mareeba
# Processing Record 606 | bonthe
# Processing Record 607 | yeppoon
# Processing Record 608 | pokosnoye
# Processing Record 609 | ahuimanu
# Processing Record 610 | kobojango
# City not found. Skipping...
# Processing Record 611 | waddan
# Processing Record 612 | wajir
# Processing Record 613 | ucluelet
# Processing Record 614 | tura
# Processing Record 615 | ostersund
# Processing Record 616 | vung tau
# Processing Record 617 | kota bahru
# Processing Record 618 | ponta delgada
# Processing Record 619 | buzmeyin
# Processing Record 620 | savannah bight
# Processing Record 621 | duvan
# Processing Record 622 | darnah
# Processing Record 623 | paka
# Processing Record 624 | tupancireta
# Processing Record 625 | wolgast
# Processing Record 626 | kuusamo
# Processing Record 627 | magdagachi
# Processing Record 628 | pringsewu
# Processing Record 629 | kefamenanu
# Processing Record 630 | mersing
# Processing Record 631 | atar
# Processing Record 632 | paramonga
# Processing Record 633 | sumbawanga
# Processing Record 634 | la asuncion
# Processing Record 635 | san cristobal
# Processing Record 636 | vreed en hoop
# City not found. Skipping...
# Processing Record 637 | kaeo
# Processing Record 638 | san angelo
# Processing Record 639 | badlapur
# Processing Record 640 | debre birhan
# Processing Record 641 | amapa
# Processing Record 642 | dhidhdhoo
# Processing Record 643 | taunggyi
# Processing Record 644 | lucapa
# Processing Record 645 | tautira
# Processing Record 646 | malyye derbety
# Processing Record 647 | alyangula
# Processing Record 648 | tsiroanomandidy
# Processing Record 649 | finnsnes
# Processing Record 650 | oudtshoorn
# Processing Record 651 | luanda
# Processing Record 652 | motygino
# Processing Record 653 | keetmanshoop
# Processing Record 654 | san jeronimo
# Processing Record 655 | qui nhon
# Processing Record 656 | mounana
# Processing Record 657 | sechura
# Processing Record 658 | awbari
# Processing Record 659 | taoudenni
# Processing Record 660 | mitu
# Processing Record 661 | shimoda
# Processing Record 662 | boryslav
# Processing Record 663 | minamiashigara
# Processing Record 664 | orlik
# Processing Record 665 | bungu
# Processing Record 666 | sinnamary
# Processing Record 667 | aguada de pasajeros
# Processing Record 668 | bacalar
# Processing Record 669 | bubaque
# Processing Record 670 | wulanhaote
# City not found. Skipping...
# Processing Record 671 | valle de allende
# Processing Record 672 | northam
# Processing Record 673 | port-cartier
# Processing Record 674 | rocha
# Processing Record 675 | mattawa
# Processing Record 676 | barcelos
# Processing Record 677 | kununurra
# Processing Record 678 | potsdam
# Processing Record 679 | puerto asis
# Processing Record 680 | gat
# Processing Record 681 | nantucket
# Processing Record 682 | pipri
# Processing Record 683 | san ignacio
# Processing Record 684 | limekilns
# Processing Record 685 | igrim
# Processing Record 686 | sorland
# Processing Record 687 | mattru
# Processing Record 688 | hobyo
# Processing Record 689 | mizan teferi
# Processing Record 690 | spas-klepiki
# Processing Record 691 | rebrikha
# Processing Record 692 | sorong
# Processing Record 693 | zambezi
# Processing Record 694 | bumbuna
# Processing Record 695 | burica
# City not found. Skipping...
# Processing Record 696 | chara
# Processing Record 697 | chkalovskoye
# Processing Record 698 | naryan-mar
# Processing Record 699 | felidhoo
# City not found. Skipping...
# Processing Record 700 | kondoa
# Processing Record 701 | banswada
# Processing Record 702 | nara
# Processing Record 703 | tabialan
# City not found. Skipping...
# Processing Record 704 | koslan
# Processing Record 705 | lerwick
# Processing Record 706 | itarema
# Processing Record 707 | bolsheustikinskoye
# City not found. Skipping...
# Processing Record 708 | termoli
# Processing Record 709 | kerteh
# City not found. Skipping...
# Processing Record 710 | eregli
# Processing Record 711 | araouane
# Processing Record 712 | poronaysk
# Processing Record 713 | cedar city
# Processing Record 714 | palabuhanratu
# City not found. Skipping...
# Processing Record 715 | apache junction
# Processing Record 716 | touros
# Processing Record 717 | itabuna
# Processing Record 718 | tazovskiy
# Processing Record 719 | caborca
# Processing Record 720 | shangrao
# Processing Record 721 | mogadishu
# Processing Record 722 | kerzhenets
# City not found. Skipping...
# Processing Record 723 | jensen beach
# Processing Record 724 | sao joao da barra
# Processing Record 725 | caravelas
# Processing Record 726 | albania
# Processing Record 727 | bridgend
# Processing Record 728 | florianopolis
# Processing Record 729 | shieli
# Processing Record 730 | medicine hat
# Processing Record 731 | kiama
# Processing Record 732 | curup
# Processing Record 733 | padilla
# Processing Record 734 | kilakarai
# Processing Record 735 | pedernales
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
new_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_order]
city_data_df.head(10)
# Out:
#           City Country                 Date      Lat       Lng  Max Temp  \
# 0       Avarua      CK  2021-10-11 00:07:20 -21.2078 -159.7750     78.85
# 1         Poum      NC  2021-10-11 00:08:42 -20.2333  164.0167     75.42
# 2  Yellowknife      CA  2021-10-11 00:04:32  62.4560 -114.3525     36.41
# 3          Hit      IQ  2021-10-11 00:08:42  33.6416   42.8251     76.91
# 4    Upernavik      GL  2021-10-11 00:08:43  72.7868  -56.1549     33.33
# 5        Moree      AU  2021-10-11 00:08:43 -29.4667  149.8500     64.42
# 6  Tvedestrand      NO  2021-10-11 00:08:44  58.6220    8.9315     48.11
# 7     Karratha      AU  2021-10-11 00:08:44 -20.7377  116.8463     78.89
# 8     Tasiilaq      GL  2021-10-11 00:08:44  65.6145  -37.6368     32.16
# 9         Naze      JP  2021-10-11 00:08:45  28.3667  129.4833     77.88
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        73         100        9.22     overcast clouds
# 1        65          11       18.66          few clouds
# 2       100         100        1.99          light rain
# 3        20           0        8.50           clear sky
# 4        97         100       10.87          light snow
# 5        82          90        9.22     overcast clouds
# 6        73          19       14.99          few clouds
# 7        30           6       21.59           clear sky
# 8        53           5        3.04           clear sky
# 9        86          64       16.46       broken clouds

# %%
output_data_file = "WeatherPy_database.csv"

city_data_df.to_csv(output_data_file, index_label="City_ID")
